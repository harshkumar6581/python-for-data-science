# %% [markdown]
# ### Inheritance in python
#
# Inheritance is a fudamental concept in Object-oriented Programing (OOP) that allow a class to inherit attributes and methods from another class. this lession covers single inheritance multiple heritance , demonstrating how to create and used them in python.

# %%
# inheritance (single inheritance)
# Parent class 

class Car:
    def __init__(self,windows,doors,enginetype):
        self.windows=windows
        self.doors=doors
        self.enginetype=enginetype


    def drive(self):
        print(f"the person will drived the {self.enginetype} car")

# %%
car1=Car(4,5,"petrol")
print(car1.drive())
# Out:
# the person will drived the petrol car
# None

# %%
car1.drive()
# Out:
# the person will drived the petrol car

# %%
class Tesla(Car):
    def __init__(self,windows,doors,enginetype, is_selfdriving):
        super().__init__(windows,doors,enginetype)
        self.is_selfdriving=is_selfdriving
    def selfdriving(self):
        print(F" Tesla support self driving :{self.is_selfdriving} car")

# %%
Tesla1=Tesla(4,5,"electric",True)
Tesla1.selfdriving()
Tesla1.doors,Tesla1.windows,
# Out:
#  Tesla support self driving :True car
# (5, 4)

# %%
Tesla1.drive()
# Out:
# the person will drived the electric car

# %%
# example
class User:
    def __init__(self):
        self.name='harsh' 

    def login(self):
        print('login')

class Student(User):

    def enroll(self):
        print('enroll into the course')


u= User()
s= Student()

print(s.name)
s.login()
s.enroll()
# Out:
# harsh
# login
# enroll into the course

# %%
print()

# %% [markdown]
# ###  Multiple inheritance

# %%
    # multilpe inheritance
    # when a class inherits from more then one base class
    ## Basse class 1

    class Animal:
        def __init__(self,name):
            self.name=name

        def speak(self):
            print("subclass must impliment this method ")
            
    # Base class2 
    class Pet:
        def __init__(self,owner):
            self.owner = owner

    ## Drive class
    class Dog(Animal,Pet):
        def __init__(self,name,owner):
            Animal.__init__(self,name)
            Pet.__init__(self,owner)

            def speak(self):
                return f"{self.name} say woof"


    ## create an object 
    Dog = Dog("buddy","harsh ")
    print(Dog.speak())
    print(f"Owner:{Dog.owner}")
# Out:
# subclass must impliment this method
# None
# Owner:harsh

# %% [markdown]
#  ####  class relation
#  - Agreegation
#  - Inheritance

# %% [markdown]
# Aggregation (Has A relationship)

# %%
# example 
class Customer:
    def __init__(self,name,gender,address):
        self.name=name
        self.gender=gender
        self.address=address

class Adress:
    def __init__(self,city,pin,state):
        self.city=city
        self.pin=pin
        self.state=state

add1=Address('gurgaon',1223233,'bihar')         
cust = Customer('harsh','male','indera colony rnchi road ramgarh jharkhand ')


# method example 
# what about privae attribute
