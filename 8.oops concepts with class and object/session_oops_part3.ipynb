# %% [markdown]
# ### Class Relationship
# - Aggregation
# - inheritance

# %% [markdown]
# ### Aggregation (Has - A relationship)

# %%
### example
class Customer:
    def __init__(self,name,gender,address):
        self.name = name
        self.gender= gender
        self.address = address

    def print_adress(self):
        print(self.address.city,self.address.pin,self.address.state)   

    def edit_profile(self,)    

class Address:
    def __init__(self,city,pin,state):
        self.city = city
        self.pin = pin
        self.state = state 

    def get_city(self):
        return self.__city   

    def edit_address(self,new_city,new_pin,new_state):
        self.__city = new_city
        self.pin = new_pin
        self.state = new_state     

add1 = Address('gurgaun',122011,'haryana')
cust = Customer('harsh','male',add1)
cust.print_adress()
cust.print_pr
# Out:
# gurgaun 122011 haryana

# %%
# example 
class Customer:
    def __init__(self,name,gender,address):
        self.name=name
        self.gender=gender
        self.address=address


    def print_adress(self):
        print(self.address.city,self.address.pin,self.address.state)


class Address:
    def __init__(self,city,pin,state):
        self.city=city
        self.pin = pin
        self.state=state 
add1=Address('ranchi',462001,'Jharkhand')
cust = Customer('harsh','male',add1)

cust.print_adress()
# Out:
# ranchi 462001 Jharkhand

# %%
# example 
class Customer:
    def __init__(self,name,gender,address):
        self.name=name
        self.gender=gender
        self.address=address


    # def print_adress(self):
    #     print(self.address.get_city,self.address.pin,self.address.state)

    def print_adress(self):
        print(self.address._Address__city,self.address.pin,self.address.state)

    def edit_profile(self,new_name,new_city,new_pin,new_state):
        self.name =new_name
        self.Address.edit_address(new_city,new_pin,new_state)


class Address:
    
    def __init__(self,city,pin,state):
        self.__city=city
        self.pin = pin
        self.state=state 
    def get_city(self):
        return self.__city

    def edit_address(self,new_name,new_city,new_pin,new_state):
        self.__city=new_city
        self.pin=new_pin
        self.state= new_state

add1=Address('ranchi',462001,'Jharkhand')
cust = Customer('harsh','male',add1)
cust.print_adress()

cust.edit_profile('harsh','bihar',213331,"jharkhand")

cust.print_adress()
# Out:
# ranchi 462001 Jharkhand
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 38
#      35 cust = Customer('harsh','male',add1)
#      36 cust.print_adress()
# ---> 38 cust.edit_profile('harsh','bihar',213331,"jharkhand")
#      40 cust.print_adress()
#
# Cell In[16], line 17, in Customer.edit_profile(self, new_name, new_city, new_pin, new_state)
#      15 def edit_profile(self,new_name,new_city,new_pin,new_state):
#      16     self.name =new_name
# ---> 17     self.Address.edit_address(new_city,new_pin,new_state)
#
# AttributeError: 'Customer' object has no attribute 'Address'

# %%
class Customer:
    def __init__(self,name,gender,address):
        self.name = name
        self.gender = gender
        self.address = address

    def print_adress(self):
        print(self.address.get_city(), self.address.pin, self.address.state)

    def edit_profile(self,new_name,new_city,new_pin,new_state):
        self.name = new_name
        self.address.edit_address(new_city,new_pin,new_state)


class Address:
    
    def __init__(self,city,pin,state):
        self.__city = city      # private variable
        self.pin = pin
        self.state = state 

    def get_city(self):
        return self.__city

    def edit_address(self,new_city,new_pin,new_state):
        self.__city = new_city
        self.pin = new_pin
        self.state = new_state


add1 = Address('ranchi',462001,'Jharkhand')
cust = Customer('harsh','male',add1)

cust.print_adress()

cust.edit_profile('harsh','bihar',213331,"Jharkhand")

cust.print_adress()
# Out:
# ranchi 462001 Jharkhand
# bihar 213331 Jharkhand

# %% [markdown]
# ### Inheritance
# - what is inharitance
# - example
# - what is inharitance

# %%
# example

#parent class
class User:
    def __init__(self):
        self.name ='harsh'
        self.gender ='male'

    def login(self):
        print('login')   

#child class
class Student(User):
    
    # def __init__(self):
    #     self.rollno=100

    def enroll(self):
        print('enroll into the course ')
        
u =User()
s =Student() 

print(s.name)
# print(s.rollno)
s.login()
s.enroll()
# Out:
# harsh
# login
# enroll into the course

# %% [markdown]
# ## What get inheritance
# - constructor
# - Non private attribute
# - Non Private method

# %%
# constructor example 2
class Phone:
    def __init__(self,price,brand,camera):
        print("inside the phone constructor ")
        self.price=price
        self.brand=brand
        self.camera=camera
    def buy(self):
        print("Buying the phone ")

class SmartPhone(Phone):
    def __init__(self,os,ram):
        self.os=os
        self.ram=ram
        print("inside the smartphone cunstructor ")

s=SmartPhone("android",13)    
# print(s.price)
# print(s.camera)
# print(s.brand)
# Out:
# inside the smartphone cunstructor

# %%
## child class cant access private member of the class

class Phone:
    def __init__(self,price,brand,camera):
        print("inside the phone constructor ")
        self.__price=price
        self.brand=brand
        self.camera=camera
    #gettetr
    def show (self):
        print(self.__price)

class SmartPhone(Phone):
    def check(self):
        print(self.__price)

s=SmartPhone(20000,"Apple",12)
print(s.brand)
s.show()
# Out:
# inside the phone constructor
# Apple
# 20000

# %%
class Parent:
    def __init__(self,num):
        self.__num=num

    def get_num(self):
        return self.__num
        
class child(Parent):
    def show(self):
        print("this is child classs ")

son=child(100)
print(son.get_num())
son.show()
# Out:
# 100
# this is child classs

# %%
class Parent:
    def _init__(self,num):
        self.__num=num
        
    def get_num(self):
        return self.__num


class Child(Parent):
    def __init__ (self,val,num):
        self.__val=val

    def get_val(self):
        return self._val

son=Child(100,10)

print("Parent: Num:",son.get_num())
print("Child: Val:", son.get_val())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[87], line 18
#      14         return self._val
#      16 son=Child(100,10)
# ---> 18 print("Parent: Num:",son.get_num())
#      19 print("Child: Val:", son.get_val())
#
# Cell In[87], line 6, in Parent.get_num(self)
#       5 def get_num(self):
# ----> 6     return self.__num
#
# AttributeError: 'Child' object has no attribute '_Parent__num'

# %%
class A:
    def __init__(self):
        self.var1=100

    def display1(self,var1):
        print("class A: ",self.var1)
class B(A):
    
    def display2(self,var1):
        
        print("class B :", self.var1)
        

obj=B()
obj.display1(200)
# Out:
# class A:  100

# %%
## method 
# Method Overriding
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone

# %%
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent ka buy method
        super().buy()

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone
# Buying a phone

# %%
# supeer -> xconstructor 
class Phone:
    def __init__(self,price,brand,camera):
        print("inside the constructor ")
        self.__price=price
        self.brand=brand
        self.camera=camera

class SmartPhone(Phone):
    def __init__ (self,price,brand,camera,os,ram):
        print("inside the smartphone constructor ")
        super().__init__(price,brand,camera)
        self.os=os
        self.ram=ram
        print("inside the smartphone constructor ")
    
s=SmartPhone(20000,"apple","12 mp","android","1gb")    

print(s.os)
print(s.brand)
# print(s.price)
# print(s._Phone_price)
s._Phone__price
# Out:
# inside the smartphone constructor
# inside the constructor
# inside the smartphone constructor
# android
# apple
# 20000

# %%
# using super outside of the class
# super can't access the variable 
# super can't be used the out side of the class
# super allwys used inside the child class 
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")
        # syntax to call parent ka buy method
        print(super().brand)

s=SmartPhone(20000, "Apple", 13)

# s.super().buy()
s.buy
# Out:
# Inside phone constructor
# <bound method SmartPhone.buy of <__main__.SmartPhone object at 0x00000259621C38C0>>

# %% [markdown]
# ### Inheritancce in summary
# - A child class inharit from the another class
# - Inharitance improve the code reuse
# - constructor improve the code reuse
# - the parent has no access to the child class
# - private property of a parent are not accessible directly in the child class
# - Child class can override the attribute or  method. This is called the method
# - super () is an inbuilt function which is used to invoke the parent class method and the constructor

# %%
class Parent:
    def __init__(self,num):
        self.__num=num
    
    def get_num(self):
        return self.__num

class Child(Parent):
    def __init__(self,num,val):
        super().__init__(num)
        self.__val=val
        
    def get_val(self):
        return self.__val
        
son=Child(100,200)
print(son.get_num())
print(son.get_val())
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.num=100

class Child(Parent):
    def __init__(self):
        super().__init__()
        self.var=200
    
    def show(self):
        print(self.num)
        print(self.var)    
son=Child()
son.show()
# Out:
# 100
# 200

# %%
class Parent:
    def __init__(self):
        self.num=100
    def show(self):
        print('parent:',self.__num)

class Child(Parent):
    def __init__(self):
        super().__init__()
        self.__var=10

    def show(self):
        print("child:",self.__var)
        
        
obj=Child()
obj.show()
# Out:
# child: 10

# %% [markdown]
# ### Type of inheritance
# - Single inheritance
# - Multiple inheritance
# - Hierarchical inheritance
# - Multiple inheritance (Diamond Problem)
# - Hybrid inheritance

# %%
## single inheritance
class Phone:
    def __init__(self,price,brand,camera):
        print("inside the constructor ")
        self.__price=price
        self.brand=brand
        self.camera=camera

    def buy(self):
        print("Buying a phone")

class SmartPhone(Phone):
    pass

SmartPhone(1000,"apple","13px").buy()
# Out:
# inside the constructor
# Buying a phone

# %%
## Hiererchical inheritance
class Phone:
    def __init__(self,price,brand,camera):
        print("inside the constructor ")
        self.__price=price
        self.brand=brand
        self.camera=camera

    def buy(self):
        print("Buying a phone")

class SmartPhone(Phone):
    pass
class FeaturePhone(Phone):
    pass


SmartPhone(1000,"apple","13px").buy()  
FeaturePhone(10,"lava","1px").buy()
# Out:
# inside the constructor
# Buying a phone
# inside the constructor
# Buying a phone

# %%
# Multiple inheritace

class Phone:
    def __init__(self,price,brand,camera):
        print("inside the constructor ")
        self.__price=price
        self.brand=brand
        self.camera=camera

    def buy(self):
        print("Buying a phone")

class Product:
    def review(self):
        print("cust review")
class SmartPhone(Phone,Product):
    pass

s=SmartPhone(1000,"apple","13px")
# FeaturePhone(10,"lava","1px").buy()
# Out:
# inside the constructor

# %%
# the diamond problem
# https://stackoverflow.com/questions/56361048/what-is-the-diamond-problem-in-python-and-why-its-not-appear-in-python2
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class Product:
    def buy(self):
        print ("Product buy method")

# Method resolution order
class SmartPhone(Phone,Product):
    pass

s=SmartPhone(20000, "Apple", 12)

s.buy()
# Out:
# Inside phone constructor
# Buying a phone

# %%
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        return 30

    def m2(self):
        return 40

class C(B):
  
    def m2(self):
        return 20
obj1=A()
obj2=B()
obj3=C()
print(obj1.m1() + obj3.m1()+ obj3.m2())
# Out:
# 70

# %%
class A:

    def m1(self):
        return 20

class B(A):

    def m1(self):
        val=super().m1()+30
        return val

class C(B):
  
    def m1(self):
        val=self.m1()+20
        return val
obj=C()
print(obj.m1())
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[18], line 18
#      16         return val
#      17 obj=C()
# ---> 18 print(obj.m1())
#
# Cell In[18], line 15, in C.m1(self)
#      14 def m1(self):
# ---> 15     val=self.m1()+20
#      16     return val
#
# Cell In[18], line 15, in C.m1(self)
#      14 def m1(self):
# ---> 15     val=self.m1()+20
#      16     return val
#
#     [... skipping similar frames: C.m1 at line 15 (2975 times)]
#
# Cell In[18], line 15, in C.m1(self)
#      14 def m1(self):
# ---> 15     val=self.m1()+20
#      16     return val
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# ### Polymorphism
# - Method Overriding
# - Method Oveloading
# - Operator Overloding

# %%
## Method overriding
# Base class
class Animal:
    def sound(self):
        print("Animal makes a sound")

# Derived class 1
class Dog(Animal):
    def sound(self):   # overriding parent method
        print("Dog barks")

# Derived class 2
class Cat(Animal):
    def sound(self):   # overriding parent method
        print("Cat meows")

# objects
a = Animal()
d = Dog()
c = Cat()

a.sound()
d.sound()
c.sound()
# Out:
# Animal makes a sound
# Dog barks
# Cat meows

# %% [markdown]
# ## Method overloding

# %%
class shape:
    def area(self,a,b=0):
        if b==0:
            return 3.14*a*a
        else:
            return a*b 



s=shape()

print(s.area(2))
print(s.area(3,4))
# Out:
# 12.56
# 12

# %% [markdown]
# ### Operator overloding

# %%
"hello "+ "harsh "
# Out:
# 'hello harsh '

# %%
4+5
# Out:
# 9

# %%
[1,2,3,4]+[4,4]
# Out:
# [1, 2, 3, 4, 4, 4]
