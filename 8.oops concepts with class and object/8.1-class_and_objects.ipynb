# %% [markdown]
# ### Class and Object
# object oriented programing (oopm)is a programing paradigm that use "object" to design applications and computer programs. oop allows for modeling real-world scenarios using classes and objects .This lession cover basics of creating classes and objects,instance variable and methods.

# %% [markdown]
# There are four main pillars of Object-Oriented Programming (OOP): Encapsulation, Abstraction, Inheritance, and Polymorphism.

# %%
# A class is a blueprint for creating a objects.attributes , methods
class car:
    pass
audi=car()
bmw=car()

print(type(audi))
print(type(bmw))
# Out:
# <class '__main__.car'>
# <class '__main__.car'>

# %%
print(audi)

# %%
print(bmw)

# %%
audi.window=5

print(audi.window)
# Out:
# 5

# %%
tata=car()
tata.doors=4
print(tata.doors)
# Out:
# 4

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
### instance valiable and method
class Dog:
    ## constructor 
    def __init__(self,name,age):
        self.name=name
        self.age=age


## create the object 


dog1=Dog("juli",22)
print(dog1.name,dog1.age)
# Out:
# harsh 22

# %%
dog2=Dog("priya",21)
print(dog2.name)
print(dog2.age)
print(dog2.name,dog2.age)
# Out:
# priya
# 21
# priya 21

# %%
# creating class
class student:
    name="harsh kumar"
    rollno="rollnumber 32"
    def __init__(self):
        print(self)
        print("adding new student in database..")
## creating object(instance)
s1=student() 
print(s1)
print(s1.name,s1.rollno)
# Out:
# ...
# adding new student in database..
# ...
# harsh kumar rollnumber 32

# %%
class laptop:
    brand="lenovo"
    model="loq5"
    ram=16
    storage=512
    color="black colour"

lap=laptop()

print(lap.brand,lap.model,lap.ram,lap.storage,lap.color)
print(laptop.brand)
# Out:
# lenovo loq5 16 512 black colour
# lenovo

# %% [markdown]
# ### __init__ function
#
# constructor all class have a function called __init_().,
# which is allready executed when the class is initiated

# %%
class student:
    ## creting class
    def __init__(self):
        pass



    def __init__(self,fullname,marks):
        self.name=fullname
        self.marks=marks


## creating object
s1 =student("ganesh", 44)
s2=student("harsh", 33)

print(s1.name,s1.marks)
print(s2.name,s2.marks)
print(s1.name,s1.marks,s2.name,s2.marks)
# Out:
# ganesh 44
# harsh 33
# ganesh 44 harsh 33

# %%
class student:
    collage_name="goverment polytechnic adityapur"
    name="anonymous" ## class attr

    def __init__(self,fullname,marks):
        self.name=fullname
        self.marks=marks


## creating object
s1 =student("ganesh", 44)
s2=student("harsh", 33)

print(s1.name,s1.marks)
print(s2.name,s2.marks)
print(s1.name,s1.marks,s2.name,s2.marks)
print(student.collage_name)
print(s1.name)
student.collage_name
print(s2.name)
print(s2.marks)
print(s1.name)
print(s1.marks)
# Out:
# ganesh 44
# harsh 33
# ganesh 44 harsh 33
# goverment polytechnic adityapur
# ganesh
# harsh
# 33
# ganesh
# 44

# %%
class car:
    def __init__(self,brandname,model,color,fuletype):
        self.brandname= brandname
        self.model= model
        self.color= color
        self.fuletype= fuletype

## creating object
e1=car("tata","nexon","black","diesel")
print(e1.brandname,e1.model,e1.color,e1.fuletype)
# Out:
# tata nexon black diesel

# %%
class laptop:
    def __init__(self,brandname,model,processor,storage,ram,colour):
        self.brandname=brandname
        self.model=model
        self.storage=storage
        self.ram=ram
        self.colour=colour
        self.processor=processor


faa=laptop("Hp","victus","i5","1TB","16gb ram","blue")
print(faa.brandname,faa.model,faa.processor,faa.storage,faa.ram,faa.colour)
# Out:
# Hp victus i5 1TB 16gb ram blue

# %%
class student:
    naam="Hatiom pandey"
    def __init__(self, fullname):
        self.name=fullname
        print(self)
        print("adding new student database..")

s1=student("harsh ")
print(s1.name) ## harsh
# Out:
# ...
# adding new student database..
# harsh

# %%
class student:
    def __init__(self,fullname):
        self.name=fullname

    def hello(self):
        print("hello",self.name)
    def welcome(self):
        print("welcome student")    
    def get_marks(self) :
        return self.marks
        print(43)   
 

s1=student("harsh")
s1.welcome()

s1.hello()
# Out:
# welcome student
# hello harsh

# %% [markdown]
# ### let's practice
# create student class that takes name and marks of 3 subject as arrangment in cunstructor. then create a method to print the average

# %%
class student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    def get_avg(self):
        total = 0
        for val in self.marks: 
            total += val
        print("Hi", self.name, "your average score is:", total/3)


s1 = student("tony stark", [99, 98, 97])
s1.get_avg()
s1.name="harsh"
s1.get_avg()
# Out:
# Hi tony stark your average score is: 98.0
# Hi harsh your average score is: 98.0

# %%
class student:
    def __init__(self,mathematics,english,science):
        self.mathematics=mathematics
        self.english=english
        self.science=science

marks=student(22,33,44)
print("mathematics",marks.mathematics,marks.english,marks.science)
# Out:
# mathematics 22 33 44

# %% [markdown]
# ### static method

# %%
  
class student:
    @staticmethod ## decorator // ## it convert a function to be a tatic method 
    def collage():
        print("ABC Collage")

# %% [markdown]
# ###  four main pillars of Object-Oriented Programming (OOP)
# -  Encapsulation
# - Abstraction
# - Inheritance
# - Polymorphism.

# %%
class car:
    def __init__(self):
        self.acc=False
        self.brk=False
        self.clutch = False

    def start(self):
        self.clutch=True
        self.acc=True
        print("car started..")

car1= car()
car1.start()
# Out:
# car started..

# %% [markdown]
# ### Let's Practice
# create account class with 2 attribute - balance account number
# create method for debit , credit & printing the balance

# %%
class Account:
    def __init__(self, bal, acc):
        self.balance = bal
        self.account = acc

    # debit method
    def debit(self, amount):
        self.balance -= amount
        print("Rs.", amount, "was debited")
        print("Total balance =", self.get_balance())

    # credit method
    def credit(self, amount):
        self.balance += amount
        print("Rs.", amount, "was credited")
        print("Total balance =", self.get_balance())

    def get_balance(self):
        return self.balance


acc1 = Account(10000, 54263)

print(acc1.balance)
acc1.debit(1000)
acc1.credit(500)
# Out:
# 10000
# Rs. 1000 was debited
# Total balance = 9000
# Rs. 500 was credited
# Total balance = 9500

# %%
## instance  variable and methods
class dog:
    ## constructor 
    def __init__(self ,name,age):
        self.name = name
        self.name =age

## create object

dog1=dog("buddy",3)        
print(dog1)
print(dog1.name)
# Out:
# ...
# 3

# %% [markdown]
# #### krish naik

# %%
## a class is a blueprint for creating objects. attributes and methods 
class car :
    pass

audi=car()
bmw=car()

print(type(car))
# Out:
# <class 'type'>

# %%
print(audi)
print(bmw)

# %%
audi.window=4
car
print(audi.window)
# Out:
# 4

# %%
tata = car()
tata.doors=4
print(tata.window)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 3
#       1 tata = car()
#       2 tata.doors=4
# ----> 3 print(tata.window)
#
# AttributeError: 'car' object has no attribute 'window'

# %%
dir(tata)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors']

# %%
## instance variable and method 
class dog:
    ### constructor 
    def __init__(self,name,age):
        self.name=name
        self.age=age
## create a object
s1=dog("harry",32)
print(s1.age,s1.name)
print(dog)
# Out:
# 32 harry
# <class '__main__.dog'>

# %%
dog2=dog("juli",22)
print(dog2.name,dog2.age)
# Out:
# juli 22

# %%
## desine a classs with instance method 
class dog:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def bark(self):
        print(f"{self.name} says woof ")

dog1=dog("buddy",3)
dog1.bark()
dog2=dog("lucy",32)
dog2.bark()
# Out:
# buddy says woof
# lucy says woof

# %%
class Dog:
    def __init__(self,Name):
        self.Name=Name

    def bark(self):
        print(f"{self.Name} say woof")

deg1=Dog("hariom")
deg1.bark(  )
omg=Dog("ganesh")
omg.bark()
# Out:
# hariom say woof
# ganesh say woof

# %%
## modling a bank account
## defining a class for bank account 
class bankaccount:
    def __init__(self,owner,balance=0):
        self.owner=owner
        self.balance=balance

    def deposit(self,amount):
        self.balance+=amount
        print(f"{amount} is deposited {self.balance}")

    def withraw(self,amount):
        if amount>self.balance:
            print("insufficient amount")
        else:
            print(f"{amount} is widraw new balance is {self.balance}") 


    def get_balance(self):
        return self.balance

## create an account
Account=bankaccount("harsh",5000)
print(Account.balance)
# Out:
# 5000

# %%
## call instance method 
Account.deposit(100)
# Out:
# 100 is deposited 5300

# %%
# widrow methow
Account.withraw(500)
# Out:
# 500 is widraw new balance is 5300

# %%
## if i want to know complete account balance
print(Account.get_balance())
# Out:
# 5300

# %% [markdown]
# ## Conclusion
# object-oriented programing (oop) allow you to model real-world scenarios using class and objects. in this lession you learn how to create a class and object define instance variable method and use them to perform various operation .Understanding these concept in fundamental to write effective and maintanable pythin code.

# %% [markdown]
# ## campusx

# %% [markdown]
# ## class and object
# - class is a set of rules that follow object

# %%
l=[1,2,3]
l.copy() ## this the object of that file
# Out:
# [1, 2, 3]

# %%
l=[1,2,3]
print(type(l))
# Out:
# <class 'list'>

# %%
l=list([1,2,3,4,4])
print(l)
print(type(1))
# Out:
# [1, 2, 3, 4, 4]
# <class 'int'>

# %%
#pascal case
"Hello world"
# Out:
# 'Hello world'

# %%
## syntax to create an object 
# objectkanaam=classkanaam()

# %%
# object literal
l=[1,2,3]
l=list()

# %%
##3 pascal case
"helloworld"
# Out:
# 'helloworld'

# %%
class Atm:

    # constructor
    def __init__(self):
        self.pin = ''
        self.balance = 0
        self.menu()

    def menu(self):
        user_input = input("""
Hi how can I help you?
1. Press 1 to create pin
2. Press 2 to change pin
3. Press 3 to check balance
4. Press 4 to withdraw
5. Anything else to exit
""")

        if user_input == "1":
            self.create_pin()

        elif user_input == "2":
            self.change_pin()

        elif user_input == "3":
            self.balance()

        elif user_input == "4":
            self.withdraw()

        else:
            exit()

    def create_pin(self):
        user_pin = input("Enter your pin: ")
        self.pin = user_pin

        user_balance = int(input("Enter balance: "))
        self.balance = user_balance

        print("Pin created successfully")
        self.menu()

    def change_pin(self):
        old_pin=input('enter old pin')

        if old_pin == self.pin:
            ## let him change the pin 
            new_pin=input('enter a pin')
            self.pin = new_pin
            self.menu()
        else:
            print("nahi karne dunga re baba ")    
            self.menu()

    def  check_balance(self):
        usser_pin=input("enter your pin ")
        if usser_pin == self.pin:
            print("your balance is ",self.balance)
        else:
            print("chal nikal yahaa se")
            self.menu()


    def withdraw(self):
        users_pin=input("enter your  pin")
        if users_pin==self.pin:
            ## alow to withdraw
            amount=int(input('enter the amount '))
            if amount<=self.balance:
                self.balance=self.balance-amount
                print("withdrawl successfil.balanceis ",self.balance)
                self.menu()
            else:
                print('abe garib')        
        else:
            print("chal nikal yaha se  , means your password is incorrect ")
        self.menu()

# %%
obj=Atm()
# Out:
# Pin created successfully
# withdrawl successfil.balanceis  867
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print(type(obj))
# Out:
# <class '__main__.Atm'>

# %%
class temp:
    def __init__(self):
        print('hello cunstructor ')
obj2=temp()
# Out:
# hello cunstructor

# %%
class Atm:

    # constructor
    def __init__(self):
        print(id(self))
        self.pin = ''
        self.balance = 0
        self.menu()

    def menu(self):
        user_input = input("""
Hi how can I help you?
1. Press 1 to create pin
2. Press 2 to change pin
3. Press 3 to check balance
4. Press 4 to withdraw
5. Anything else to exit
""")

        if user_input == "1":
            self.create_pin()

        elif user_input == "2":
            self.change_pin()

        elif user_input == "3":
            self.check_balance()

        elif user_input == "4":
            self.withdraw()

        else:
            exit()

    def create_pin(self):
        user_pin = input("Enter your pin: ")
        self.pin = user_pin

        user_balance = int(input("Enter balance: "))
        self.balance = user_balance

        print("Pin created successfully")
        self.menu()

    def change_pin(self):
        old_pin=input('enter old pin')

        if old_pin == self.pin:
            ## let him change the pin 
            new_pin=input('enter a pin')
            self.pin = new_pin
            self.menu()
        else:
            print("nahi karne dunga re baba ")    
            self.menu()

    def  check_balance(self):
        usser_pin=input("enter your pin ")
        if usser_pin == self.pin:
            print("your balance is ",self.check_balance())
        else:
            print("chal nikal yahaa se")
            self.menu()


    def withdraw(self):
        users_pin=input("enter your  pin")
        if users_pin==self.pin:
            ## alow to withdraw
            amount=int(input('enter the amount '))
            if amount<=self.balance:
                self.balance=self.balance-amount
                print("withdrawl successfil.balanceis ",self.balance)
                self.menu()
            else:
                print('abe garib')        
        else:
            print("chal nikal yaha se  , means your password is incorrect ")
        self.menu()

# %%
obj3=Atm()
# Out:
# 2159077469952
# Pin created successfully
# chal nikal yahaa se
# your balance is  None
# your balance is  None
# your balance is  None
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
id(obj3)
# Out:
# 2473579257856

# %% [markdown]
# ### Creating own data type in python

# %%
3/4*1/2
# Out:
# 0.375

# %%
class fraction:
    ## parameterized constructor
    def __init__(self,x,y):
        self.num=x
        self.den=y

        
    def __str__(self):
        return '{}/{}'.format(self.num,self.den)


    def __add__(self,other):
        new_num=self.num*other.den+other.num*self.den
        new_den=self.den*other.den
        return '{}/{}'.format(new_num,new_den)
    def __sub__(self,other):
        new_num=self.num*other.den - other.num*self.den
        new_den=self.den*other.den
        return '{}/{}'.format(new_num,new_den)
    def __mul__(self,other):
        new_num=self.num*other.den*other.num*self.den
        new_den=self.den*other.den
        return '{}/{}'.format(new_num,new_den)
    def __truediv__(self,other):
        new_num=self.num*other.den/other.num*self.den
        new_den=self.den*other.den
        return '{}/{}'.format(new_num,new_den)

    def convert_to_decimal(self):
        return self.num/self.den

# %%
fr1=fraction(4,9)

fr2=fraction(4,8)

# %%
print(type(fr1))
print(fr1)
print(fr2)
# Out:
# <class '__main__.fraction'>
# 4/9
# 4/8

# %%
print(fr1+fr2)
print(fr1-fr2)
print(fr1*fr2)
print(fr1/fr2)
# Out:
# 68/72
# -4/72
# 1152/72
# 72.0/72

# %%
fr1.convert_to_decimal()
# Out:
# 0.4444444444444444

# %%
s1={1,1,1}
s2={3,4,5}

# %%
print(fr1-fr2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 print(fr1-fr2)
#
# TypeError: unsupported operand type(s) for -: 'fraction' and 'fraction'
