# %% [markdown]
# ### Understanding Exception
#
# Eception handlng in python always you to handle errors and takefully and corrective action without stoping the execution of the program . this lession will cover the basics of the exceptions including how to use try, except,else , and finally block.
#
# ### What are Exceotion
#
# Exception are event that disrupt the normal flow of the program execution . common exception include :
#
# - ZeroDivisionError: Dividing by zero.
# - FileNotFoundError: File not found.
# - ValueError: Invalid value.
# - TypeError: Invalid type.

# %%
a=10

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
a==b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 a==b
#
# NameError: name 'b' is not defined

# %%
## exception try , except block
try:
    a=b
except:
    print("the variable has not been assigned")
# Out:
# the variable has not been assigned

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
desult=1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 desult=1/0
#
# ZeroDivisionError: division by zero

# %%
try:
    result=1/0
except ZeroDivisionError as ex:
    print(ex)
    print("please enter the denominator grater then 0")
# Out:
# division by zero
# please enter the denominator grater then 0

# %%
try:
    result=1/4
    a=b
except ZeroDivisionError as ex:
    print(ex)
    print("please enter the denominator grater then 0")
except Exception  as ex1:
    print(ex1)  
    print('main exception got caught here')
# Out:
# name 'b' is not defined
# main exception got caught here

# %%
try:
    num=int(input("enter a number"))
    result=10/num
except ValueError:
    print("This is not a valid number ")  
except ZeroDivisionError:
    print("enter denominator grater then zero 0")   
except Exception as ex:
    print(ex)    
else:
    print(f"the result is {result}")
# Out:
# the result is 2.0

# %%
## try , except,else block 
try:
    num=int(input("enter a number"))
    result=10/num
except ValueError:
    print("that's not a valid number!")
except ZeroDivisionError:
    print("you can't divided by zero !")   
except Exception as ex:
    print(ex)
else:
    print(f"the result is {result}")
finally:
    print("execution complete.")
# Out:
# the result is 3.3333333333333335
# execution complete.

# %%
## file handling and the exception handling 
try:
    file=open('example1.txt','r')
    content=file.read()
    print(content)
except FileNotFoundError:
    print("the file does not exist")    

except Exception as ex:
    print(ex)
finally:
    if 'file' in locals() and not file.closed():
        file.close()
        print('fileclose')
# Out:
# the file does not exist
