# %% [markdown]
# ### Standard Library overview
#
# python standard library is a vast collection of modules and packages that come bundled with python,
# providing the wide range of functionality out of box. Here an some overview of some of the most commonly used modules and packages in python standard library.

# %% [markdown]
# impoer arr

# %%
import array
arr=array.array('i',[1,2,3,4,])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## random 
import random
print(random.randint(1,22))
print(random.choice(['apple','banana','cherry']))
print(random.choice(['das,cos','single','master']))
# Out:
# 22
# apple
# single

# %%
import random

def play_game():
    options = ["rock", "paper", "scissors"]
    computer_choice = random.choice(options)
    user_choice = input("Choose Rock, Paper, or Scissors: ").lower()

    print(f"\nYou chose: {user_choice}")
    print(f"Computer chose: {computer_choice}\n")

    if user_choice == computer_choice:
        print("It's a tie!")
    elif user_choice == "rock" and computer_choice == "scissors":
        print("You win! Rock beats scissors.")
    elif user_choice == "paper" and computer_choice == "rock":
        print("You win! Paper covers rock.")
    elif user_choice == "scissors" and computer_choice == "paper":
        print("You win! Scissors cut paper.")
    else:
        print(f"You lose! {computer_choice} beats {user_choice}.")

play_game()
# Out:
# You chose: rock
# Computer chose: paper
#
# You lose! paper beats rock.

# %%
import random
def game_play():
    option=["rock","paper","scissor"]
    comp_choice=random.choice(option)
    user_choice=input("choose Rock,paper,or scissor:").lower()
    print(f"\n you chose: {user_choice}")
    print(f"\n computer chose: {comp_choice}")
    if user_choice==comp_choice:
        print("tie")
    elif user_choice=="rock" and comp_choice=="scissor":
        print("you will win ")
    elif user_choice=="paper" and comp_choice=="rock":
        print("you will win ")
    elif user_choice=="scissors" and comp_choice=="paper":
        print("you will win ")   
    else:
        print(f"you lose ") 
game_play()
# Out:
#  you chose: rock
#
#  computer chose: paper
# you lose

# %%
## file and directory access
import os
print(os.getcwd())
# Out:
# d:\python for data science\5.importing creating module and packages

# %%
os.mkdir('test_dir')

# %%
## high level operation on files and collection of sile 
import shutil
shutil.copyfile('source.txt',"estination.txt")
# it wlii easily copy
# Out:
# 'estination.txt'

# %%
# data serialization 
import json 
data={'name':'harsh','age':21}
json_str=json.dumps(data)
print(json_str)
print(type(json_str))


parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "harsh", "age": 21}
# <class 'str'>
# {'name': 'harsh', 'age': 21}
# <class 'dict'>

# %%
## csv 
import csv
with open('example.csv',mode='w',newline='') as file :
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['harsh',21])


with open('example.csv',mode='r') as file:
       reader=csv.reader(file)
       for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['harsh', '21']

# %%
## datetime 
for datetime import datetime,timedelta 
now=datetime.now()
print(now)
# Out:
#   Cell In[15], line 2
#     for datetime import datetime,timedelta
#                  ^
# SyntaxError: invalid syntax

# %%
from datetime import datetime,timedelta
now=datetime.now()
print(now)
# Out:
# 2026-02-13 21:53:10.145063

# %%
yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-02-12 21:53:10.145063

# %%
## time 
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1771000238.7725325
# 1771000240.7737012

# %%
## regular expresiion 
import re 
pattern=r'\d+'
text='there are 123 apples'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123
