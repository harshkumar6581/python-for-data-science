# %% [markdown]
# ### Iterator
#
# iterator are the  advance python concept that allow for efficient looping and memory managment . iterator provide a way to access element of a collection sequentially without exposing the underlining the structur.

# %%
mt_list=[1,2,3,4]
for i in mt_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
type(mt_list)
# Out:
# list

# %%
print(mt_list)
# Out:
# [1, 2, 3, 4]

# %%
## iterator 

iterator=iter(mt_list)
print(type(iterator))
# Out:
# <class 'list_iterator'>

# %%
iterator

# %%
## iterator through all the element 

next(iterator)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[15], line 3
#       1 ## iterator through all the element
# ----> 3 next(iterator)
#
# StopIteration:

# %%
# iterator=iter(mt_list)
try:
    print(next(iterator))
except StopIteration:
    print("there are no any element in the iterator")
# Out:
# there are no any element in the iterator

# %%
# string iterator 
my_string = "Hello"
string_iterator=iter(my_string)

print(next(string_iterator))
print(next(string_iterator))
# Out:
# H
# e

# %% [markdown]
# ### Campus x

# %% [markdown]
# ### what is an iteration
# Iteration is a general term for taking each item of something, one after another. Any time you use a loop, explicit or implicit, to go over a group of items, that is iteration.

# %%
## example
num=[1,2,3]

for i in num:
    print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ### Iterator
# An Iterator is an object that allows the programmer to traverse through a sequence of data without having to store the entire data in the memory

# %%
L =[x for x in range(1,10000)]

# # for i in l:
# #     print(i*2)

# for i in L:
#     print(i**2)
import sys
print(sys.getsizeof(L)/64)

x=range(1,10000000)
# for i in X:
    # print(i*2)

print(sys.getsizeof(x)/64)
# Out:
# 1330.875
# 0.75

# %% [markdown]
# ### What is Iterable
# Iterable is an object, which one can iterate over
# It generates an Iterator when passed to iter() method.

# %%
### Example
L=[1,2,3]
type(L)

# l is in iterable 
type(iter(L))

## iter(L)-- > iterator
# Out:
# list_iterator

# %% [markdown]
# ### Point to remember
# - every iterator is also and iterable
# - Not all iterables are iterators

# %% [markdown]
# ### 🔹 Iterator vs Iterable
# Iterable → something you can loop over (list, tuple, string)
# Iterator → actual object that gives next values

# %%
a=2
a
# for i in a:
#     print(i)

dir(a)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
# ...

# %%
T={1:2,3:3}
dir(T)#dir() is a built-in function that shows all properties and methods (attributes) of an object.
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
L=[1,2,3]
dir(L)## L is not an iterator
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
L=[1,2,3]
## L is not an iterator
dir(iter(L))
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__length_hint__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %% [markdown]
# #### Understanding how for loop work

# %%
num = [1,2,3]

for i in num:
    print(i)
# Out:
# 1
# 2
# 3

# %%
num=[1,2,3]

# fetches the iterator 
iter_num=iter(num)

# step2 ---> next
next(iter_num)
next(iter_num)
next(iter_num)
# Out:
# 3

# %%
def mera_khudka_forloop(iterable):

    iterator = iter(iterable)

    while True:
        try:
            print(next(iterator))
        except stop:
            break

# %%
a=[1,2,3]
b=range(1,11)
c=(1,2,3)
d={1,2,3}
e={0:1,1:1}

# %% [markdown]
# ### A confusing point

# %%
num = [1,2,3]
iter_obj=iter(num)
dir(iter_obj)
print(id(iter_obj),'Adress of iterator 1')

iter_obj2 = iter(iter_obj)
print(id(iter_obj2),'Adress of iterator 2')
# Out:
# 2066454440128 Adress of iterator 1
# 2066454440128 Adress of iterator 2

# %%
class mera_range:
    def __init__(self,start,end):
        self.start=start
        self.end=end

    def __iter__(self):
        return mera_range_iterator(self)

# %%
class mera_range_iterator:
    def __init__(self,iterable_obj):
        self.iterable=iterable_obj
        pass
    def __iter__(self):
        return self

    def __next__(self):
        
        if self.iterable.start>= self.iterable.end:
            raise stopiteration

        current = self.iterable.start
        self.iterable.start+=1
        return current

# %%
x= mera_range(1,11)

# %%
type(x)
# Out:
# __main__.mera_range

# %%
iter(x)
