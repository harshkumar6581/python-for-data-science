# %% [markdown]
# ### syntax and demantics in python
# - single line comment and multilie comment
# - Defination of syntax and symantics
# - Basic syntax rule in python
# - Understanding semantics in python
# - common syntax error and how to avoid them
# - Practical code example

# %% [markdown]
# syntax refers to the set of rules that defines the combination of symbols that are consider to be correctly structured program in a language
# - in simple word :- it is all about correct arragement of words and symbol in a code.

# %% [markdown]
# semantics refers to the meaning of the interpretation of the symbol, character , command in a language . it is about what the code is suppoted to do when it runs.
# - it is all about the correct meaning of the word ,symbol and character.

# %%
### basic syntax in python

# %%
### this is singlr line comment 
'''
this is the example of multiline comment \n

python is a dynamically type programing language 
because it does't neet to because it does't need to
declear data type of a variable.
'''
# Out:
# '\nthis is the example of multiline comment \n\n\n'

# %%
## basic syntax rule in python 
### case sensitive - python is a case sensitive 
name = 'harsh'
Name = 'kumar'

print(name)
print(Name)
# Out:
# harsh
# kumar

# %% [markdown]
# ### Indntation
# Indentation in Python is used to define the structure and hierarchy of the code. Unlike many other programming languages that use braces {} to delimit blocks of code, Python uses indentation to determine the grouping of statements. This means that all the statements within a block must be indented at the same level.

# %%
## indentation 
## python used to define blocks of code . consistent use of space (commony 4) or a table is required.

age=32
if age>30:
    
    print(age)

print(age)
# Out:
# 32
# 32

# %%
## this is single loine comment 
print("helloo harsh")
# Out:
# helloo harsh

# %%
## line continuation
### use a backslace (\) to continue a statement to the next line 
total=1+2+3+4+5+6+7+\
4+5+6


print(total)
# Out:
# 43

# %%
## multiple stTEMENT ON single line 
x=5;y=10;z=x+y
print(z)

F=3;G=23;H=F*G
print(H)
# Out:
# 15
# 69

# %%
## Understanding semantics in python.
## variable assignment.
age=32## age is an integer
name="harsh" # name is a string

# %%
# typr inference
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## type inference
variable =10
print(type(variable))
variable="harsh"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
age=32
if age>30:
    print(age)
# Out:
# 32

# %%
# name error 
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 # name error
# ----> 2 a=b
#
# NameError: name 'b' is not defined

# %%
## code example of indentation 
if True:
    print("correct incentation ")
    if False:
        print("this not print")
    print("this will print ")    
print("outside the if block ")
# Out:
# correct incentation
# this will print
# outside the if block
