# %% [markdown]
# #### Topic ottline
#
#       1. introduction to the control statement
#       2.if statement
#       3.else statement
#       4.elif statement
#       5.nested conditional statement
#       6. practical example
#       7.common erroer and best practices

# %% [markdown]
# # Python Control Statements (Notes)
#
# - **1. Introduction to Control Statements**
#   - Allow programs to make decisions and control the flow of execution based on conditions.
#   - Execute specific blocks of code only when certain conditions are met.
#
# - **2. If Statement**
#   - Executes a block of code **only if a condition is True**.
#   - Syntax:
#     ```python
#     if condition:
#         # code to execute
#     ```
#   - Example:
#     ```python
#     age = 20
#     if age >= 18:
#         print("You are an adult.")
#     ```
#
# - **3. Else Statement**
#   - Executes a block of code **if the if condition is False**.
#   - Syntax:
#     ```python
#     if condition:
#         # code if True
#     else:
#         # code if False
#     ```
#   - Example:
#     ```python
#     age = 16
#     if age >= 18:
#         print("You are an adult.")
#     else:
#         print("You are not an adult.")
#     ```
#
# - **4. Elif Statement**
#   - Checks **multiple conditions** after an if statement.
#   - Syntax:
#     ```python
#     if condition1:
#         # code1
#     elif condition2:
#         # code2
#     else:
#         # code3
#     ```
#   - Example:
#     ```python
#     marks = 80
#     if marks >= 90:
#         print("Grade: A")
#     elif marks >= 75:
#         print("Grade: B")
#     elif marks >= 50:
#         print("Grade: C")
#     else:
#         print("Grade: D")
#     ```
#
# - **5. Nested Conditional Statement**
#   - An `if` or `else` inside another `if` or `else`.
#   - Example:
#     ```python
#     age = 20
#     has_id = True
#
#     if age >= 18:
#         if has_id:
#             print("You can vote.")
#         else:
#             print("You need an ID to vote.")
#     else:
#         print("You are not eligible to vote.")
#     ```
#
# - **6. Practical Example**
#   - Check eligibility for a driving license:
#     ```python
#     age = int(input("Enter your age: "))
#     citizen = True
#
#     if age >= 18:
#         if citizen:
#             print("You are eligible for a driving license.")
#         else:
#             print("You must be a citizen to apply.")
#     else:
#         print("You are not eligible yet.")
#     ```
#
# - **7. Common Errors and Best Practices**
#   - **Common Errors:**
#     - Indentation errors:
#       ```python
#       if age >= 18:
#       print("Adult")  # ❌
#       ```
#       Correct:
#       ```python
#       if age >= 18:
#           print("Adult")  # ✅
#       ```
#     - Using `=` instead of `==` in conditions:
#       ```python
#       if age = 18:  # ❌
#       if age == 18: # ✅
#       ```
#   - **Best Practices:**
#     - Keep conditions simple and readable.
#     - Avoid deeply nested `if` statements.
#     - Use descriptive variable names.

# %%
##  if statement 
age=30

if age>=18:
    print("you are allowed to vote in the election")
# Out:
# you are allowed to vote in the election

# %%
age>=18
# Out:
# True

# %%
### else statement
## the else statement execute a block of code if the condition in the if statement is false.

age =17

if age>=18:
    print("you are eligible for voting")

else:
    print("you are not eligible for voting")
# Out:
# you are not eligible for voting

# %%
## elif statement
## the elif statement allow you to check multiple condition . it stands for "else , if"

age=12

if age<13:
    print("you are a child")
elif age<18:
    print("you are a teenager")
else:
    print("you are adult")
# Out:
# you are a child

# %%
## nested conditional statement
## you can place one or more if,elif,or else statement inside another if , else, elif, statement to create nested conditional statements.
 
## number even,odd or negative.

num=int(input("enter the number"))

if num>0:
    print("the number is positive")
    if num%2==0:
        print("the number is even")
    else:
       print(" the number is odd ")   


else:
    print("the number is zero or negative")
# Out:
# the number is positive
# the number is even

# %%
## practical example

## determine if a year is leap year
year=int(input("enter the year"))

if year%4==0:
    if year%100==0:
        if year%400==0:
            print("is a leap year",year)

        else:
            print("this is not a leap year",year)  
    else:
        print(year,"is a leap year")
else:
    print(year,"is not a leap year")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       1 ## practical example
#       2
#       3 ## determine if a year is leap year
# ----> 4 year=int(input("enter the year"))
#       6 if year%4==0:
#       7     if year%100==0:
#
# ValueError: invalid literal for int() with base 10: 't55'

# %%
## assignment
## simpe calculator program
## take user input

num1=float(input("enter first number:"))
num2=float(input("enter second number:"))
operation=input("enter operation(+,-,*,/,)")


## perform the required operation 
if operation =='+':
    result=num1+num2
elif operation =="-":
    result=num1-num2
elif operation =='*':
  result=num1*num2
elif operation == '/':
     if num2 !=0:
         result=num1/num2
     else:
         result= "error! division by zero"   
else:
    result="invalid operation."
print("result:",result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 5
#       1 ## assignment
#       2 ## simpe calculator program
#       3 ## take user input
# ----> 5 num1=float(input("enter first number:"))
#       6 num2=float(input("enter second number:"))
#       7 operation=input("enter operation(+,-,*,/,)")
#
# ValueError: could not convert string to float: '77+55'

# %%
### determine the ticket price based on age and wheder the persion is a student
age= int(input("enter your age:"))
is_student=input("are you a student? (yes/no):")

# determine tickets price
if age<5:
    price ="free"
elif age<=12:
    price="$10"
elif age<=17:
    if ia_student=='yes':   
        price = "$12"
    else:
        price="$15"
elif age <=64:
    if is_student=='yes':
         price="$18"
