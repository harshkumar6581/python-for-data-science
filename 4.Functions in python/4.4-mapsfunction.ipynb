# %% [markdown]
# ### the map function in the python
#
#
# The map() function applies a given function to all items in an input list (or any other iterable) and returns a map object (an iterator). This is particularly useful for transforming data in a list comprehensively.

# %%
def square(x):
    return x*x
square(10)
# Out:
# 100

# %%
number=[1,2,3,4,5,6,7]
list(map(lambda x:x*x,number))
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
list(map(square,number))
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
## lambda function with map 
number = [1,2,3,4,5,6,7,8]
list(map(lambda x:x*x,number))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
## map multiple iterable 
number1=[1,2,3]
number2=[4,5,6]
addition_number=list(map(lambda x,y:x*y,number1,number2))
print(addition_number)
# Out:
# [4, 10, 18]

# %%
## map () to convert a list of sting to integers 
# use map to convert string to integers 
str_numbers=['1','2','3','4','5']
int_numbers=list(map(int,str_numbers))
print(int_numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
list(map(int,int_numbers))
# Out:
# [1, 2, 3, 4, 5]

# %%
words=['apple','banana','cherry']
upper_word=list(map(str.upper,words))

print(upper_word)
# Out:
# ['APPLE', 'BANANA', 'CHERRY']

# %%
def get_name(person):
    return person['name']
people=[
    {'name':'harsh','age':21},
    {'name':'hariom','age':32}
]
list(map(get_name,people))
# Out:
# ['harsh', 'hariom']

# %% [markdown]
# Conclusion
# The map() function is a powerful tool for applying transformations to iterable data structures. It can be used with regular functions, lambda functions, and even multiple iterables, providing a versatile approach to data processing in Python. By understanding and utilizing map(), you can write more efficient and readable code.
