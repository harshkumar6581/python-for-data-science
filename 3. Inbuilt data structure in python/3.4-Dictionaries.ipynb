# %% [markdown]
# Video Outline:
# 1. Introduction to Dictionaries
# 2. Creating Dictionaries
# 3. Accessing Dictionary Elements
# 4. Modifying Dictionary Elements
# 5. Dictionary Methods
# 6. Iterating Over Dictionaries
# 7. Nested Dictionaries
# 8. Dictionary Comprehensions
# 9. Practical Examples and Common Errors

# %% [markdown]
# Introduction to Dictionaries
#
# Dictionaries are unordered collections of items. They store data in key-value pairs. Keys must be unique and immutable (e.g., strings, numbers, or tuples), while values can be of any type.

# %%
### creating dictionaries 
empty_dict={}
print(type(empty_dict))
print(empty_dict)
# Out:
# <class 'dict'>
# {}

# %%
empty_dict=dict()
empty_dict
# Out:
# {}

# %%
student={"name":"harsh","age":21,"grade":"a"}
print(student)
print(type(student))
# Out:
# {'name': 'harsh', 'age': 21, 'grade': 'a'}
# <class 'dict'>

# %%
student={"name":"harsh","age":21,"name":"a"}
print(student)
# Out:
# {'name': 'a', 'age': 21}

# %%
### Accessing dictionary element 
student={"name":"harsh","age":21,"grade":"a"}
print(student)
# Out:
# {'name': 'harsh', 'age': 21, 'grade': 'a'}

# %%
## Accessing dictionary name 

print(student['grade'])
print(student['age'])
print(student['name'])

## accesing using() method 
print(student.get('grade'))
print(student.get('last_name'))
print(student.get('last_name ',"not available "))
# Out:
# a
# 21
# harsh
# a
# None
# not available

# %%
### modifying dictionary elements
### dictionary are mutable, so you can add, update or delete elements.
print(student)
# Out:
# {'name': 'harsh', 'age': 21, 'grade': 'a'}

# %%
student["age"]=33 ## upate value for key
print(student)
student["address"]="india"## added a new key and value 

print(student)
# Out:
# {'name': 'harsh', 'age': 33, 'grade': 'a'}
# {'name': 'harsh', 'age': 33, 'grade': 'a', 'address': 'india'}

# %%
del student['grade']

print(student)
# Out:
# {'name': 'harsh', 'age': 33, 'address': 'india'}

# %%
student
# Out:
# {'name': 'harsh', 'age': 33, 'address': 'india'}

# %%
del student['grade'] 
print(student)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 del student['grade']
#       2 print(student)
#
# KeyError: 'grade'

# %%
## dictionary method 

keys=student.keys()## get all keyes 
print(keys)

value=student.values()## get al values 
print(value)

items =student.items()
print(items)
# Out:
# dict_keys(['name', 'age', 'address'])
# dict_values(['harsh', 33, 'india'])
# dict_items([('name', 'harsh'), ('age', 33), ('address', 'india')])

# %% [markdown]
# ### shallo copy

# %%
### shallo copy
student
# Out:
# {'name': 'harsh', 'age': 33, 'address': 'india'}

# %%
student_copy=student
print(student)
print(student_copy)
# Out:
# {'name': 'harsh', 'age': 33, 'address': 'india'}
# {'name': 'harsh', 'age': 33, 'address': 'india'}

# %%
student["name"]="hariom"
print(student )
print(student_copy)
# Out:
# {'name': 'hariom', 'age': 33, 'address': 'india'}
# {'name': 'hariom', 'age': 33, 'address': 'india'}

# %%
student_copy=student.copy()
print(student_copy)
print(student)
# Out:
# {'name': 'hariom', 'age': 33, 'address': 'india'}
# {'name': 'hariom', 'age': 33, 'address': 'india'}

# %%
student['name']="harsh2"
print(student_copy)
print(student )
# Out:
# {'name': 'hariom', 'age': 33, 'address': 'india'}
# {'name': 'harsh2', 'age': 33, 'address': 'india'}

# %%
#### Iterating over dictionaries
### you can use loop to iterate over dictionaries.key ,values and items 

### iteration over keys
for keys in student.keys():
    print(keys)
# Out:
# name
# age
# address

# %%
### iterate over values
for value in student.values():
    print(value)
# Out:
# harsh2
# 33
# india

# %%
### Iterate over key value pairs
for key,value in student.items():
    print(f"{key}:{value}")
# Out:
# name:harsh2
# age:33
# address:india

# %%
### Nested dictionaries

student={
    "student1":{"name":"harsh","age":32},
    "student2":{"name":"hariom","age":52}

}
print(student)
# Out:
# {'student1': {'name': 'harsh', 'age': 32}, 'student2': {'name': 'hariom', 'age': 52}}

# %%
### acess nested dictionaries element 
print(students["student2"]["name"])
print(students["student2"]["age"])
# Out:
# hariom
# 35

# %%
student.items()
# Out:
# dict_items([('name', 'ganesh'), ('age', 33), ('address', 'india')])

# %%
## iterating overnested dictionaried 
for student_id,student_info in student.items():
    print(f"{student_id}:{student_info}")
    for key,value in student_info.items():
        print(f"{key}:{value}")
# Out:
# student1:{'name': 'harsh', 'age': 32}
# name:harsh
# age:32
# student2:{'name': 'hariom', 'age': 52}
# name:hariom
# age:52

# %%
## Iterating over nested dictionaries
for student_id, student_info in students.items():
    print (f" (student_id): (student_info)")
    for key, value in student_info.items():
        print("{key}: {value}")
# Out:
#  (student_id): (student_info)
# {key}: {value}
# {key}: {value}
#  (student_id): (student_info)
# {key}: {value}
# {key}: {value}

# %%
#### Ditionary coprehention 
squares={x:x**2 for x in range(5)}
print(squares)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %%
square={x**2 for x in range(19)}
print(square)
# Out:
# {0, 1, 256, 4, 9, 16, 144, 25, 289, 36, 169, 49, 64, 196, 324, 81, 225, 100, 121}

# %%
#### conditional dictionary comrehention
squares_even={x:x**2 for x in range (10) if x%2==0}
print(squares_even)
# Out:
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64}

# %%
## Practical eamples

### Use a dictionary to count he frequency of the element in list 

number=[1,3,3,3,2,3,3,3,4,4,4,4]
frequency={}

for number in number:
   if number in frequency:
        frequency[number]+=1
    else:
        frequency[number]=1
print(frequency)
# Out:
#   File <string>:11
#     else:
#          ^
# IndentationError: unindent does not match any outer indentation level

# %%
###merge 2 dictionaries into one 
dict1={"a":1,"b":2}
dict2={"b":3,"c":4}
merged_dict={**dict1,**dict2}
print(merged_dict)
# Out:
# {'a': 1, 'b': 3, 'c': 4}
