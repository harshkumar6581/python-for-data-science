# %% [markdown]
# ### Tuples

# %% [markdown]
# -  Introduction to the tuples
# -  how  to create tuples
# -  Accessing Tuple element
# -  tuple operation
# -  immutable nature of tuples
# -  tuplenmethod
# -  paking and unpaking tuples
# -  nested tuples
# -  practical example and comman error

# %%
### creating a tuple
empty_tuple=()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst=list()
print(type(lst))
tpl=tuple()
print(type(tpl))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
number=tuple([1,2,3,4,5,6])
number
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
list((1,2,3,4,5,6))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
mix_tuple=(1,"hello world",3.14,True)
print(mix_tuple)
# Out:
# (1, 'hello world', 3.14, True)

# %%
## accessing tuple
number
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
number[0]
# Out:
# 1

# %%
print(number[2])
print(number[-1])
# Out:
# 3
# 6

# %%
number[0:4]
# Out:
# (1, 2, 3, 4)

# %%
number[::]
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
## Tuples operation 

concatination_tuple=number +mix_tuple ## it is used to combine two things 
print(concatination_tuple)
# Out:
# (1, 2, 3, 4, 5, 6, 1, 'hello world', 3.14, True)

# %%
print(mix_tuple*3)
# Out:
# (1, 'hello world', 3.14, True, 1, 'hello world', 3.14, True, 1, 'hello world', 3.14, True)

# %%
mix_tuple*3
# Out:
# (1,
#  'hello world',
#  3.14,
#  True,
#  1,
#  'hello world',
#  3.14,
#  True,
#  1,
#  'hello world',
#  3.14,
#  True)

# %%
number*3
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)

# %%
## immutable nature of tuples
## tupless are immutable, meaning their element cannot be changed once assigned
lst=[1,2,3,4,5]
print(lst)
# Out:
# [1, 2, 3, 4, 5]

# %%
lst[1]="krish"
print(lst)
# Out:
# [1, 'krish', 3, 4, 5]

# %%
number
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
number[1]="harsh"
number
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 number[1]="harsh"
#       2 number
#
# TypeError: 'tuple' object does not support item assignment

# %%
## tuple method

number
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
print(number.count(1))
print(number.index(3))
# Out:
# 1
# 2

# %%
## paking and unpaking tuple

packed_tuple=1,"hello",3.14 ## it is known as paking tuple

print(packed_tuple)
# Out:
# (1, 'hello', 3.14)

# %%
## unpaking a tuple
a,b,c=packed_tuple ## unpaking the tuple 


print(a)
print(b)
print(c)
# Out:
# 1
# hello
# 3.14

# %%
## unpaking with star *
number=(1,2,3,4,5,6)
first,*middle,last=number
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %%
## nested tuple
## nested list
lst=[[1,2,3,4],[6,7,8,9],[1,"hello",3.14,"c"]]
lst[0][2]
# Out:
# 3

# %%
lst[1][2]
# Out:
# 8

# %%
lst[0][0:3]
# Out:
# [1, 2, 3]

# %%
lst=[[1,2,3,4],[6,7,8,9],(1,"hello",3.14,"c")]
lst[2][0:3]
# Out:
# (1, 'hello', 3.14)

# %%
nested_tuple=((1,2,3),("a","b","c"),(True,False))


## acces the element inside a tuple 
print(nested_tuple[0])
print(nested_tuple[-1])
print(nested_tuple[1][1])
# Out:
# (1, 2, 3)
# (True, False)
# b

# %%
#3 iterating over nested tuple
for sub_tuple in nested_tuple:
    for item in sub_tuple:
        print(item,end=" ")
# Out:
# 1 2 3 a b c True False

# %%
for sub_tuple in nested_tuple:
    print(sub_tuple)
# Out:
# (1, 2, 3)
# ('a', 'b', 'c')
# (True, False)

# %%
lst=[[[1,2,3,4],[6,7,8,9]],(1,"hello",3.14,"c")]
lst[0][0:3]
# Out:
# [[1, 2, 3, 4], [6, 7, 8, 9]]

# %%
nested_tuple=((1,2,3),("a","b","c"),(True,False))

# %%
sorry="sorry"

# %%
a=6
for i in range(a):
    if i== 3:
        pass
    print(i, end=" ")
# Out:
# 0 1 2 3 4 5

# %%
food ="burger"
food.replace("e","a")
print(food)
# Out:
# burger

# %%
list=[2,1,3]
print(list.sort())
# Out:
# None

# %%
name ="python"
if name=="java" or "html":
    print("login successful")
else:
    print("authentication failed")
# Out:
# login successful

# %%
num = "03012345678"
print(num[-4:])
# Out:
# 5678
