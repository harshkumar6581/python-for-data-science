# %% [markdown]
# ### File operation - read and write files
#
# file handling is the crucial part of any programing language . python provide in built in functino and method to read from abd write to files , both text and binsry . this lessons will cover the basics of file handling , including reading and writing text file and binary files

# %%
## reading  a whole file 

with open('example.txt','r') as file:
    content=file.read()
    print(content)
# Out:
# hello how are you ?
# im good
# welcome to my home

# %%
with open('geek.txt','r') as file:
    file=file.read()
    print(file)
# Out:
# Hello world
# GeeksforGeeks
# 123 456

# %%
## read my file line by line 
with open ('example.txt','r') as file:
    for line in file:
        print(line.strip())## strip() remove the new line character
# Out:
# hello how are you ?
# im good
# welcome to my home

# %%
## writing a file (overwriting)
with open('example.txt','w') as infile: ## w is a keyword for writing files 
    infile.write('hello word')
    infile.write('\nthis is a new line')

# %%
## write a file (without overwriting )
with open('example.txt','w') as harsh:
    harsh.write('\nthis is a append line. append operation taking place ')

# %%
### writing a list of lines to a file 
lines=['first line\n','second line\n','thrd line']
with open('example.txt','a') as file:
    file.writelines(lines)

# %%
handling=['''File handling refers to the process 
of performing operations on a file, such as creating,
 opening, reading, writing and closing it through a
  programming interface. It involves managing the data 
  flow between the program and the file system on the
  storage device,ensuring that data is handled safely
  and efficiently.''']

with open('example.txt','w') as file:
    file.writelines(handling)

# %%
### binary files 
all_file_handling=['''File Handling in Python
Last Updated : 10 Dec, 2025
File handling refers to the process of performing operations on a file, such as creating, opening, reading, writing and closing it through a programming interface. It involves managing the data flow between the program and the file system on the storage device, ensuring that data is handled safely and efficiently.

Why do we need File Handling
To store data permanently, even after the program ends.
To access external files like .txt, .csv, .json, etc.
To process large files efficiently without using much memory.
To automate tasks like reading configs or saving outputs.
Opening a File
To open a file, we can use open() function, which requires file-path and mode as arguments.

Note: We will use a sample file named geek.txt for all examples in this article. To download click here 

Syntax:

file = open('filename.txt', 'mode')

filename.txt: name (or path) of the file to be opened.
mode: mode in which you want to open the file (read, write, append, etc.).
Note: If you don’t specify the mode, Python uses 'r' (read mode) by default.

Basic Example: Opening a File

f = open("geek.txt", "r")
print(f)
Explanation: This code opens file geek.txt in read mode. If the file exists, it returns a file object connected to that file; if the file does not exist, Python raises a FileNotFoundError.

Closing a File
The file.close() method closes the file and releases the system resources. If the file was opened in write or append mode, closing ensures that all changes are properly saved.




file = open("geek.txt", "r")
# Perform file operations
file.close()
We will also see later how closing can be handled automatically using the with statement and how to ensure files close properly using exception handling.

Checking File Properties
Once the file is open, we can check some of its properties:




f = open("geek.txt", "r")
print("Filename:", f.name)
print("Mode:", f.mode)
print("Is Closed?", f.closed)
​
f.close()
print("Is Closed?", f.closed)
Output:

Filename: geek.txt
Mode: r
Is Closed? False
Is Closed? True

Explanation:

f.name: Returns the name of the file that was opened (in this case, "geek.txt").
f.mode: Tells us the mode in which the file was opened. Here, it’s 'r' which means read mode.
f.closed: Returns a boolean value- False when file is currently open otherwise True.
Reading a File
Reading a file can be achieved by file.read() which reads the entire content of the file. After reading, it’s good practice to close the file to free up system resources.

Example: Reading a File in Read Mode (r)




file = open("geek.txt", "r")
content = file.read()
print(content)
file.close()
Output:

Hello world
GeeksforGeeks
123 456

Writing a File
In Python, writing to a file is done using the mode "w". This creates a new file if it doesn’t exist, or overwrites the existing file if it does. The write() method is used to add content. After writing, make sure to close the file.

Example: Writing to a file (overwrites if file exists)




with open("geek.txt", "w") as file:
    file.write("Hello, Python!\n")
    file.write("File handling is easy with Python.")
​
print("File written successfully")
Output:

Hello, Python!
File handling is easy with Python.

Explanation:

"w" mode opens the file for writing (overwrites existing content if the file already exists).
write() method adds new text to the file.
When using with, the file closes automatically at the end of the block.
Using with Statement
Instead of manually opening and closing the file, you can use the with statement, which automatically handles closing. This reduces the risk of file corruption and resource leakage.

Example: Let's assume we have a file named geek.txt that contains text "Hello, World!".




with open("geek.txt", "r") as file:
    content = file.read()
    print(content)
Output:

Hello, World!

Handling Exceptions When Closing a File
It's important to handle exceptions to ensure that files are closed properly, even if an error occurs during file operations. Here, the finally block ensures the file is closed even if an error occurs.




try:
    file = open("geek.txt", "r")
    content = file.read()
    print(content)
finally:
    file.close()
Output:

Hello, World!

Explanation:

try: Starts the block to handle code that might raise an error.
open(): Opens the file in read mode.
read(): Reads the content of the file.
finally: Ensures the code inside it runs no matter what.''']
with open('example.txt','w') as map:
    map.writelines(all_file_handling)

# %%
## binary files 
## writing a binary files 
data = b'\x00\x01\x03\x04'
with open('example.bin','wb') as file:
    file.write(data)

# %%
## reading binary files 
with open ('example.bin','rb') as file:
    content=file.read()
    print(content)
# Out:
# b'\x00\x01\x03\x04'

# %%
## read the content from source text file and write to a destination text file 
with open('source.txt','r') as source_file:
    content= source_file.read()

with open('destination.txt','w') as destination_file:
    destination_file.write(content)

# %%
## read  a text file and count the number of lines, words ,and character,
## counting lines , word , and character in  A text files
def count_text_file(file_path):
    with open(file_path,'r') as file:
        lines=file.readlines()
        line_count= len(lines)
        word_count=sum(len(line.split()) for line in lines)
        char_count=sum(len(lines) for line in lines)
    return line_count,word_count,char_count


file_path='example.txt'
lines ,words,characters=count_text_file(file_path)
print(f'lines:{lines} ,words:{words} ,characters:{characters}')
# Out:
# lines:143 ,words:704 ,characters:20449

# %% [markdown]
# the w+ mode in python is used to oppen a file for both reading and writing . if the file does not exist , it will created . if the file exists , its content is truncrated (i,e.., the file overwriting )

# %%
## writing and reading the file 
# the w+ mode in python is used to oppen a file for both reading and writing . if the file does not exist , it will created . if the file exists , its content is truncrated (i,e.., the file overwriting )
with open('exiample.txt','w+') as file:
    file.write("hello word\n")
    file.write("this is a new line\n")


    # ## move the file cursor to the beginingn
    file.seek(0)

    ## read the congtent of the file 
    content=file.read()
    print(content)
    # file.seek(0)
# Out:
# hello word
# this is a new line

# %% [markdown]
# ### Create a new directory

# %%
## create a new directory
import os
new_directory ="package"
os.mkdir(new_directory)
print(f"directory '{new_directory}' create")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[45], line 4
#       2 import os
#       3 new_directory ="package"
# ----> 4 os.mkdir(new_directory)
#       5 print(f"directory '{new_directory}' create")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'package'

# %%
### listing files and directories
items=os.listdir('.')
print(items)
# Out:
# ['destination.txt', 'document.txt', 'example.bin', 'example.txt', 'exiample.txt', 'filehandlingquestions.ipynb', 'filehandlingsolution.ipynb', 'fileoperation.ipynb', 'geek.txt', 'log.txt', 'output.txt', 'package', 'sample.txt', 'source.txt', 'students.txt', 'tasks.json', 'To-Do List App (File Based).ipynb']

# %%
## joining path 
dir_name="folder"
file_name="file.txt"
full_path=os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
dir_name="folder"
file_name="file.txt"
full_path=os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# d:\python for data science\6. File handling in python\folder\file.txt

# %%
## it wiil show the perticular path are exist or not in the package
path='example1.txt'
if os.path.exists(path):
    print(f"the path'{path}' exists")
else:
    print(f"the path '{path}' does not exists")
# Out:
# the path 'example1.txt' does not exists

# %%
path1='example.bin'
if os.path.exists(path):
    print(f"exist path'{path1}'exists")
else:
    print(f"the path'{path}'path doesnot exist")
# Out:
# the path'example1.txt'path doesnot exist

# %%
## getting the absolute path
relative_path='element.txt'
absolute_path=os.path.abspath(relative_path)
print(absolute_path)
# Out:
# d:\python for data science\6. File handling in python\element.txt
